# %%
pip install streamlit

# %%
# !pip install streamlit pyngrok pandas

# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
# !ngrok config add-authtoken 304xVuwn20ARDyn4bq1F1gs8DO9_6KvnAMPDfex3Qw5qDc4Uy

# %%
# %%writefile app.py
import streamlit as st

st.title("Streamlit App Running in Colab 🚀")
st.write("If you see this in your browser, it is working correctly.")

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

# Title and headers
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Read CSV into DataFrame
    dataFrame = pd.read_csv(uploadfile)

    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Display DataFrame
    st.dataframe(dataFrame)

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

# Display a movie poster at the top
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Title and headers
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Read CSV into DataFrame
    dataFrame = pd.read_csv(uploadfile)

    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Display DataFrame
    st.dataframe(dataFrame)

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

# Display movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Display uploaded file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV into DataFrame
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Display column names
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Show first 5 rows
    st.write("### First 5 Rows of Your Data:")
    st.dataframe(dataFrame.head())

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Show file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Show columns
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Show first 5 rows
    st.write("### First 5 Rows of Your Data:")
    st.dataframe(dataFrame.head())

    # Show describe summary
    st.write("### Data Description (Summary Statistics):")
    st.dataframe(dataFrame.describe())

    # Show missing values
    st.write("### Missing Values in Each Column:")
    st.write(dataFrame.isnull().sum())

    # Correlation heatmap
    st.write("### Correlation Heatmap:")
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.heatmap(dataFrame.corr(), annot=True, fmt=".2f", cmap="coolwarm", ax=ax)
    st.pyplot(fig)

    # Histogram
    st.write("### Histogram Plot:")
    numeric_columns = dataFrame.select_dtypes(include=['float', 'int']).columns.tolist()
    if numeric_columns:
        selected_column = st.selectbox("Select a numeric column for histogram", numeric_columns)
        fig, ax = plt.subplots()
        sns.histplot(dataFrame[selected_column], kde=True, ax=ax)
        ax.set_title(f"Histogram for {selected_column}")
        st.pyplot(fig)
    else:
        st.info("No numeric columns available for histogram.")

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

# Movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Show file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Show columns
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Show first 5 rows
    st.write("### First 5 Rows of Your Data:")
    st.dataframe(dataFrame.head())

    # Show describe summary
    st.write("### Data Description (Summary Statistics):")
    st.dataframe(dataFrame.describe())

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Show file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Show columns
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Checkbox: Show first 5 rows
    if st.checkbox("Show first 5 rows of data"):
        st.write("### First 5 Rows:")
        st.dataframe(dataFrame.head())

    # Checkbox: Show describe summary
    if st.checkbox("Show data description (.describe())"):
        st.write("### Data Description (Summary Statistics):")
        st.dataframe(dataFrame.describe())

    # Checkbox: Show missing values
    if st.checkbox("Show missing values per column"):
        st.write("### Missing Values:")
        st.write(dataFrame.isnull().sum())

    # Checkbox: Show correlation heatmap
    if st.checkbox("Show correlation heatmap"):
        st.write("### Correlation Heatmap:")
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.heatmap(dataFrame.corr(), annot=True, fmt=".2f", cmap="coolwarm", ax=ax)
        st.pyplot(fig)

    # Checkbox: Show histogram
    if st.checkbox("Show histogram plot for a column"):
        numeric_columns = dataFrame.select_dtypes(include=['float', 'int']).columns.tolist()
        if numeric_columns:
            selected_column = st.selectbox("Select numeric column for histogram", numeric_columns)
            fig, ax = plt.subplots()
            sns.histplot(dataFrame[selected_column], kde=True, ax=ax)
            ax.set_title(f"Histogram for {selected_column}")
            st.pyplot(fig)
        else:
            st.info("No numeric columns available for histogram.")

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Show file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Show columns
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Selectbox for analysis selection
    analysis_option = st.selectbox(
        "Select the analysis you want to view:",
        (
            "Show first 5 rows",
            "Show data description (.describe())",
            "Show missing values per column",
            "Show correlation heatmap",
            "Show histogram plot for a column"
        )
    )

    if analysis_option == "Show first 5 rows":
        st.write("### First 5 Rows:")
        st.dataframe(dataFrame.head())

    elif analysis_option == "Show data description (.describe())":
        st.write("### Data Description (Summary Statistics):")
        st.dataframe(dataFrame.describe())

    elif analysis_option == "Show missing values per column":
        st.write("### Missing Values:")
        st.write(dataFrame.isnull().sum())

    elif analysis_option == "Show correlation heatmap":
        st.write("### Correlation Heatmap:")
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.heatmap(dataFrame.corr(), annot=True, fmt=".2f", cmap="coolwarm", ax=ax)
        st.pyplot(fig)

    elif analysis_option == "Show histogram plot for a column":
        numeric_columns = dataFrame.select_dtypes(include=['float', 'int']).columns.tolist()
        if numeric_columns:
            selected_column = st.selectbox("Select numeric column for histogram", numeric_columns)
            fig, ax = plt.subplots()
            sns.histplot(dataFrame[selected_column], kde=True, ax=ax)
            ax.set_title(f"Histogram for {selected_column}")
            st.pyplot(fig)
        else:
            st.info("No numeric columns available for histogram.")

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Movie poster
st.image(
    "https://upload.wikimedia.org/wikipedia/en/b/bc/Interstellar_film_poster.jpg",
    caption="Interstellar (2014)",
    use_column_width=True
)

# Titles
st.title("Student of the AI/ML/DS")
st.header("AI")
st.subheader("DS")

# File uploader
uploadfile = st.file_uploader('Upload .csv files only', type=['csv'])

if uploadfile is not None:
    # Show file name
    file_name = uploadfile.name
    st.write(f"**Uploaded File Name:** {file_name}")

    # Read CSV
    dataFrame = pd.read_csv(uploadfile)
    st.subheader("Data uploaded successfully")
    st.success('CSV file uploaded successfully!')

    # Show columns
    columns = dataFrame.columns.tolist()
    st.write("**Columns in the file:**")
    st.write(columns)

    # Selectbox for analysis selection
    analysis_option = st.selectbox(
        "Select the analysis you want to view:",
        (
            "Show first 5 rows",
            "Show data description (.describe())",
            "Show missing values per column",
            "Show correlation heatmap",
            "Show histogram plot for a column"
        )
    )

    if analysis_option == "Show first 5 rows":
        st.write("### First 5 Rows:")
        st.dataframe(dataFrame.head())

    elif analysis_option == "Show data description (.describe())":
        st.write("### Data Description (Summary Statistics):")
        st.dataframe(dataFrame.describe())

    elif analysis_option == "Show missing values per column":
        st.write("### Missing Values:")
        st.write(dataFrame.isnull().sum())

    elif analysis_option == "Show correlation heatmap":
        st.write("### Correlation Heatmap:")
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.heatmap(dataFrame.corr(), annot=True, fmt=".2f", cmap="coolwarm", ax=ax)
        st.pyplot(fig)

    elif analysis_option == "Show histogram plot for a column":
        numeric_columns = dataFrame.select_dtypes(include=['float', 'int']).columns.tolist()
        if numeric_columns:
            selected_column = st.selectbox("Select numeric column for histogram", numeric_columns)
            fig, ax = plt.subplots()
            sns.histplot(dataFrame[selected_column], kde=True, ax=ax)
            ax.set_title(f"Histogram for {selected_column}")
            st.pyplot(fig)
        else:
            st.info("No numeric columns available for histogram.")

else:
    st.error('No file uploaded yet. Please upload a CSV file to proceed.')

# %%
# !ngrok config add-authtoken 305OvU2m4whMWEYcgCe90YSBbX4_7zRFw2PtrZyjfGXM6CDRY

# %%
# !pip install pyngrok streamlit

import threading
from pyngrok import ngrok

# Install ngrok authtoken if not done already
# !ngrok authtoken YOUR_AUTHTOKEN_HERE

# Create a simple Streamlit app file
with open("app.py", "w") as f:
    f.write("""
import streamlit as st
st.title("🦜 Streamlit + Ngrok Test")
st.write("If you see this, your ngrok + Streamlit setup works in Colab!")
""")

# Start Streamlit in a thread
def start_streamlit():
    import subprocess
    subprocess.run(["streamlit", "run", "app.py"])

thread = threading.Thread(target=start_streamlit)
thread.start()

# Connect ngrok AFTER starting Streamlit
public_url = ngrok.connect(addr="8501")
print(f"🔗 Your Streamlit app URL: {public_url}")
